# %% [markdown]
# ## 1. Line Plot
#
# A line plot is used to display data points connected by straight lines.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

plt.plot(x, y, marker='o')
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.title("Line Plot")
plt.show()

# %% [markdown]
# ## 2. Bar Plot
#
# A bar plot is used to compare values of different categories.

# %%
import matplotlib.pyplot as plt

x = ["A", "B", "C", "D", "E"]
y = [25, 40, 30, 50, 35]

plt.bar(x, y)
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Bar Plot")
plt.show()

# %% [markdown]
# ## 3. Scatter Plot
#
# A scatter plot is used to show the relationship between two numerical variables.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [10, 15, 12, 20, 18, 25]

plt.scatter(x, y)
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# ## 4. Histogram
#
# A histogram is used to represent the frequency distribution of numerical data.

# %%
import matplotlib.pyplot as plt

data = [10, 20, 15, 25, 30, 20, 15, 35, 40, 25,
        30, 20, 15, 45, 35, 25, 30, 40, 20, 15]

plt.hist(data, bins=5)
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.show()
